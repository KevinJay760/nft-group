# %% [markdown]
# ### Documentation for Wax API
#  - https://developer.wax.io/dapps/wax-rpc-api/
#  - https://developers.eos.io/manuals/eos/latest/nodeos/plugins/chain_api_plugin/api-reference/index
#
# Possibly also worth checking out (not included in this notebook yet)
#  - https://wax.api.atomicassets.io/atomicmarket/docs/swagger/#/

# %%
import requests
import json
import pandas as pd

# %%
#Arbitrarily chosen block
block_num = 116770550

# %%
#Construct url
api_endpoint = 'https://chain.wax.io'
api_request = '/v1/chain/get_block'

url = api_endpoint + api_request

# %%
#Send request
headers = {'Content-type': 'application/json'}
post_data = '{"block_num_or_id": "' + str(block_num) + '"}'

response = requests.post(url, data = post_data, headers = headers)

# %%
#Peek at the response data
raw_json = json.loads(response.text)
raw_json
# Out:
# {'timestamp': '2021-04-30T23:46:44.000',
#  'producer': 'ledgerwiseio',
#  'confirmed': 0,
#  'previous': '06f5c6f51519a1ae40b442d2771d6cb7aca7db09c1537031d54e887bc7375014',
#  'transaction_mroot': '7b53bcd2f919a0b9675ead1b04995b068bffa17319c150ab0de0a08664e6b56c',
#  'action_mroot': '6f1b7311a528f24f059f3450bdbdba40f50666813699ba681e409edfed932772',
#  'schedule_version': 228,
#  'new_producers': None,
#  'producer_signature': 'SIG_K1_JvnegFNJ3gVs4L5ASAuPgpABn2f54u2DUKjuDxU7kvp9nD2UA8To5iFxfMLy9PDnvxMoT19QB9gD8mN2UTjKitHifbhZbg',
#  'transactions': [{'status': 'executed',
#    'cpu_usage_us': 100,
#    'net_usage_words': 0,
#    'trx': '2cbf842b637599745427d6133fbfb20aa9f51985e34ef293e1e04ed0e19ec212'},
#   {'status': 'executed',
#    'cpu_usage_us': 706,
#    'net_usage_words': 16,
#    'trx': {'id': '84c303b78b0fafd7217cc30eb70eaf39f874d4faa216509ef0b9cb2b2a360e29',
# ...

# %%
#Load transactions into a pandas dataframe
df = pd.DataFrame(raw_json['transactions'])
df
# Out:
#       status  cpu_usage_us  net_usage_words  \
# 0   executed           100                0
# 1   executed           706               16
# 2   executed           100                0
# 3   executed           464               16
# 4   executed           480               16
# 5   executed           522               34
# 6   executed           470               16
# 7   executed           825               47
# 8   executed           492               16
# 9   executed           482               16
# 10  executed           434               16
# 11  executed           453               39
# 12  executed           470               39
# 13  executed           413               16
# 14  executed           408               16
# 15  executed           453               16
# 16  executed           465               16
# 17  executed           399               16
# 18  executed           376               16
# 19  executed           470               16
# ...
